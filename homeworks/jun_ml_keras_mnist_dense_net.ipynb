# %% [markdown]
# # Домашнее задание
#
# В этом домашнем задании вам предстоит обучить модель классификации рукописных цифр на Tensorflow.
#
# Важным дополнительным требованием будет сохранение чекпоинтов на ваш гугл диск (не переживайтеЖ ниже будут подсказки, как это сделать). Это пригодится вам в дальнейшем при обучении более сложных моделей, на случай потери данных при неожиданном отключении Colab.

# %%
import tensorflow as tf
print(tf.__version__)
from google.colab import drive
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.layers import Dense

tf.executing_eagerly()
# Out:
# 2.4.1
# True

# %% [markdown]
# ####Вспомогательный код

# %%
#@title 
def show_mnist(images, labels, predicted_labels=None):
    plt.figure(figsize=(10,10))
    for i in range(16):
        plt.subplot(4,4, i+1)
        plt.xticks([])
        plt.yticks([])
        plt.grid(False)
        plt.imshow(images[i], cmap=plt.cm.gray)
        if predicted_labels is not None:
            title_obj = plt.title(f"Real: {labels[i]}. Pred: {predicted_labels[i]}")
            if labels[i] != predicted_labels[i]:
                plt.setp(title_obj, color='r')
        else:
            plt.title(f"Real label: {labels[i]}")

def show_progress(history: dict):
    plt.figure(figsize=(10, 5))
    ax1 = plt.subplot(1,2,1)    
    plt.plot(history["accuracy"],label='train accuracy')
    plt.plot(history["val_accuracy"], label='test accuracy')
    ax2 = plt.subplot(1,2,2)
    plt.plot(history["loss"],label='train_loss')
    plt.plot(history["val_loss"],label='test_loss')
    
    ax1.legend(loc='best')
    ax2.legend(loc='best')
    plt.grid()
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Загрузка данных

# %%
(x_train, y_train),(x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

show_mnist(x_train, y_train)
x_train = x_train.reshape((-1, 28*28)) # вытянули каждую картинку в вектор
x_test = x_test.reshape((-1, 28*28))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
# прикрепим ваш гугл диск к виртуальной машине
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Путь до вашего гугл диска скорее всего выглядит так: /content/drive/My Drive/
# если эта клетка вызывает ошибку, 
# измените путь согласно ! ls "/content/drive/"

path = Path("/content/drive/My Drive/Skillbox/model_1")
path.mkdir(exist_ok=True, parents=True) # папка создается на вашем гугл диске. вместе с "родителями"
assert path.exists()
cpt_filename = "best_checkpoint.hdf5"  
cpt_path =str(path / cpt_filename)
# После выполнения этой клетки, в вашем гугл диске должна создаться папка: Skillbox/model_1
# убедитесь в этом
checkpoint = tf.keras.callbacks.ModelCheckpoint(cpt_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

# %% [markdown]
# А весь код ниже вы реализуете самостоятельно! Вы уже к этому готовы :)
# Требования к модели:
# 1. Точность на тестовой части выборки >96%
# 2. Чекпоинт модели с лучшими параметрами должен быть сохранен у вас на гугл диске
# 3. Объект history, который получается из model.fit(...) должен содержать значения лосса и accuracy для трейна и теста

# %%
# < YOUR CODE STARTS HERE >
model = tf.keras.Sequential()
model.add(Dense(512, input_shape=(784,), activation='relu'))
model.add(Dense(256, activation='relu'))
# model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

optimizer = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(loss='sparse_categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# < YOUR CODE ENDS HERE >

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               401920
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 535,818
# Trainable params: 535,818
# Non-trainable params: 0
# _________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
history = model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=50, batch_size=32, verbose=1,
                    callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.3192 - accuracy: 0.9032 - val_loss: 0.0940 - val_accuracy: 0.9703
#
# Epoch 00001: val_loss improved from inf to 0.09404, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 2/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0797 - accuracy: 0.9761 - val_loss: 0.0909 - val_accuracy: 0.9719
#
# Epoch 00002: val_loss improved from 0.09404 to 0.09092, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 3/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0523 - accuracy: 0.9833 - val_loss: 0.0794 - val_accuracy: 0.9764
#
# Epoch 00003: val_loss improved from 0.09092 to 0.07942, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 4/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0385 - accuracy: 0.9877 - val_loss: 0.0791 - val_accuracy: 0.9783
#
# Epoch 00004: val_loss improved from 0.07942 to 0.07908, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 5/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0304 - accuracy: 0.9905 - val_loss: 0.0742 - val_accuracy: 0.9792
#
# Epoch 00005: val_loss improved from 0.07908 to 0.07417, saving model to /content/drive/My Drive/Skillbox/model_1/best_checkpoint.hdf5
# Epoch 6/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0240 - accuracy: 0.9919 - val_loss: 0.0989 - val_accuracy: 0.9765
#
# Epoch 00006: val_loss did not improve from 0.07417
# Epoch 7/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0218 - accuracy: 0.9935 - val_loss: 0.0776 - val_accuracy: 0.9801
#
# Epoch 00007: val_loss did not improve from 0.07417
# Epoch 8/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0182 - accuracy: 0.9940 - val_loss: 0.0877 - val_accuracy: 0.9808
#
# Epoch 00008: val_loss did not improve from 0.07417
# Epoch 9/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0144 - accuracy: 0.9954 - val_loss: 0.1032 - val_accuracy: 0.9801
#
# Epoch 00009: val_loss did not improve from 0.07417
# Epoch 10/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0164 - accuracy: 0.9955 - val_loss: 0.0805 - val_accuracy: 0.9828
#
# Epoch 00010: val_loss did not improve from 0.07417
# Epoch 11/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.1057 - val_accuracy: 0.9791
#
# Epoch 00011: val_loss did not improve from 0.07417
# Epoch 12/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0171 - accuracy: 0.9952 - val_loss: 0.0960 - val_accuracy: 0.9824
#
# Epoch 00012: val_loss did not improve from 0.07417
# Epoch 13/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0135 - accuracy: 0.9958 - val_loss: 0.0951 - val_accuracy: 0.9821
#
# Epoch 00013: val_loss did not improve from 0.07417
# Epoch 14/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0130 - accuracy: 0.9960 - val_loss: 0.0865 - val_accuracy: 0.9822
#
# Epoch 00014: val_loss did not improve from 0.07417
# Epoch 15/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.0946 - val_accuracy: 0.9816
#
# Epoch 00015: val_loss did not improve from 0.07417
# Epoch 16/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0106 - accuracy: 0.9967 - val_loss: 0.1253 - val_accuracy: 0.9782
#
# Epoch 00016: val_loss did not improve from 0.07417
# Epoch 17/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0112 - accuracy: 0.9973 - val_loss: 0.1096 - val_accuracy: 0.9812
#
# Epoch 00017: val_loss did not improve from 0.07417
# Epoch 18/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0104 - accuracy: 0.9972 - val_loss: 0.1237 - val_accuracy: 0.9794
#
# Epoch 00018: val_loss did not improve from 0.07417
# Epoch 19/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0083 - accuracy: 0.9974 - val_loss: 0.1195 - val_accuracy: 0.9800
#
# Epoch 00019: val_loss did not improve from 0.07417
# Epoch 20/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0104 - accuracy: 0.9974 - val_loss: 0.1193 - val_accuracy: 0.9801
#
# Epoch 00020: val_loss did not improve from 0.07417
# Epoch 21/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.1168 - val_accuracy: 0.9821
#
# Epoch 00021: val_loss did not improve from 0.07417
# Epoch 22/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0079 - accuracy: 0.9975 - val_loss: 0.1216 - val_accuracy: 0.9828
#
# Epoch 00022: val_loss did not improve from 0.07417
# Epoch 23/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0100 - accuracy: 0.9973 - val_loss: 0.1272 - val_accuracy: 0.9834
#
# Epoch 00023: val_loss did not improve from 0.07417
# Epoch 24/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0082 - accuracy: 0.9979 - val_loss: 0.1352 - val_accuracy: 0.9802
#
# Epoch 00024: val_loss did not improve from 0.07417
# Epoch 25/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.1631 - val_accuracy: 0.9791
#
# Epoch 00025: val_loss did not improve from 0.07417
# Epoch 26/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0124 - accuracy: 0.9970 - val_loss: 0.1290 - val_accuracy: 0.9832
#
# Epoch 00026: val_loss did not improve from 0.07417
# Epoch 27/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0077 - accuracy: 0.9979 - val_loss: 0.1465 - val_accuracy: 0.9814
#
# Epoch 00027: val_loss did not improve from 0.07417
# Epoch 28/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0072 - accuracy: 0.9981 - val_loss: 0.1518 - val_accuracy: 0.9809
#
# Epoch 00028: val_loss did not improve from 0.07417
# Epoch 29/50
# 1875/1875 [==============================] - 13s 7ms/step - loss: 0.0071 - accuracy: 0.9983 - val_loss: 0.1521 - val_accuracy: 0.9828
#
# Epoch 00029: val_loss did not improve from 0.07417
# Epoch 30/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.1867 - val_accuracy: 0.9806
#
# Epoch 00030: val_loss did not improve from 0.07417
# Epoch 31/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 0.1418 - val_accuracy: 0.9822
#
# Epoch 00031: val_loss did not improve from 0.07417
# Epoch 32/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 0.1386 - val_accuracy: 0.9829
#
# Epoch 00032: val_loss did not improve from 0.07417
# Epoch 33/50
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 0.1561 - val_accuracy: 0.9825
#
# Epoch 00033: val_loss did not improve from 0.07417
# Epoch 34/50
# 1875/1875 [==============================] - 12s 7ms/step - loss: 0.0081 - accuracy: 0.9984 - val_loss: 0.1938 - val_accuracy: 0.9822
#
# Epoch 00034: val_loss did not improve from 0.07417
# Epoch 35/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0100 - accuracy: 0.9978 - val_loss: 0.1849 - val_accuracy: 0.9812
#
# Epoch 00035: val_loss did not improve from 0.07417
# Epoch 36/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0089 - accuracy: 0.9986 - val_loss: 0.1570 - val_accuracy: 0.9823
#
# Epoch 00036: val_loss did not improve from 0.07417
# Epoch 37/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0047 - accuracy: 0.9985 - val_loss: 0.1701 - val_accuracy: 0.9811
#
# Epoch 00037: val_loss did not improve from 0.07417
# Epoch 38/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.1884 - val_accuracy: 0.9838
#
# Epoch 00038: val_loss did not improve from 0.07417
# Epoch 39/50
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0051 - accuracy: 0.9987 - val_loss: 0.1754 - val_accuracy: 0.9828
#
# Epoch 00039: val_loss did not improve from 0.07417
# Epoch 40/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.1883 - val_accuracy: 0.9806
#
# Epoch 00040: val_loss did not improve from 0.07417
# Epoch 41/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.1664 - val_accuracy: 0.9844
#
# Epoch 00041: val_loss did not improve from 0.07417
# Epoch 42/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0105 - accuracy: 0.9979 - val_loss: 0.2010 - val_accuracy: 0.9809
#
# Epoch 00042: val_loss did not improve from 0.07417
# Epoch 43/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.2036 - val_accuracy: 0.9838
#
# Epoch 00043: val_loss did not improve from 0.07417
# Epoch 44/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 0.2229 - val_accuracy: 0.9819
#
# Epoch 00044: val_loss did not improve from 0.07417
# Epoch 45/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0106 - accuracy: 0.9979 - val_loss: 0.2255 - val_accuracy: 0.9833
#
# Epoch 00045: val_loss did not improve from 0.07417
# Epoch 46/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0052 - accuracy: 0.9990 - val_loss: 0.2117 - val_accuracy: 0.9820
#
# Epoch 00046: val_loss did not improve from 0.07417
# Epoch 47/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0084 - accuracy: 0.9985 - val_loss: 0.2556 - val_accuracy: 0.9803
#
# Epoch 00047: val_loss did not improve from 0.07417
# Epoch 48/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0089 - accuracy: 0.9983 - val_loss: 0.2006 - val_accuracy: 0.9830
#
# Epoch 00048: val_loss did not improve from 0.07417
# Epoch 49/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0031 - accuracy: 0.9993 - val_loss: 0.1907 - val_accuracy: 0.9843
#
# Epoch 00049: val_loss did not improve from 0.07417
# Epoch 50/50
# 1875/1875 [==============================] - 11s 6ms/step - loss: 0.0049 - accuracy: 0.9992 - val_loss: 0.2178 - val_accuracy: 0.9826
#
# Epoch 00050: val_loss did not improve from 0.07417

# %%
assert len(list(path.glob("*"))) != 0, f"Checkpoint dir {path}"
assert "accuracy" in history.history, "History object must contain Accuracy. Please, retrain with this metric"
assert "val_accuracy" in history.history, "Please, provide validation_data in model.fit."
assert np.max(history.history["val_accuracy"]) > 0.95, "Validation accuracy must be more than 0.95"
# Для старой версии (tf.__version__ == 1.x) запустить aseert-ы ниже:
# assert "acc" in history.history, "History object must contain Accuracy. Please, retrain with this metric"
# assert "val_acc" in history.history, "Please, provide validation_data in model.fit."
# assert np.max(history.history["val_acc"]) > 0.95, "Validation accuracy must be more than 0.95"
print("Training tests passed")
# Out:
# Training tests passed

# %% [markdown]
# Давайте посмотрим на графики обучения:

# %%
show_progress(history.history)

# %% [markdown]
# А теперь перейдем к загрузке модели. Если все реализовано правильно, то код ниже должен сработать без ошибок:

# %%
restored_model = tf.keras.models.load_model(cpt_path)
loss, acc = restored_model.evaluate(x_test, y_test)
print(f"Accuracy of restored model {acc*100 :.2f}%")
assert acc > 0.96
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0742 - accuracy: 0.9792
# Accuracy of restored model 97.92%

# %% [markdown]
# И, наконец, можно сравнить предсказания с реальными классами (с такой точностью найти ошибку будет сложно):

# %%
predicted_labels = restored_model.predict_classes(x_test)
idxs = np.random.choice(np.arange(len(x_test)), 16, replace=False)
show_mnist(x_test[idxs].reshape((-1, 28, 28)), y_test[idxs], predicted_labels[idxs])
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
